# %% [markdown]
# <a href="https://colab.research.google.com/github/jakewalter/intro_seismology/blob/main/earthquake_location.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This problem is from Chapter 5 for the first earthquake

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Load data
q1 = np.array([[30.   , 30.   , 10.   ],
       [ 9.   , 24.   , 13.51 ],
       [24.   , 13.2  , 13.212],
       [33.   ,  4.8  , 13.907],
       [45.   , 10.8  , 14.056],
       [39.   , 27.   , 11.191],
       [54.   , 30.   , 14.204],
       [15.   , 39.   , 13.088],
       [36.   , 42.   , 12.236],
       [27.   , 48.   , 13.027],
       [48.   , 48.   , 13.745],
       [15.   , 42.   , 13.318],
       [18.   , 15.   , 12.763],
       [30.   , 36.   , 10.536]])
stationx = q1[1:, 0]
stationy = q1[1:, 1]
ts1 = q1[1:, 2]
N = len(stationx)
originalX = q1[0, 0]
originalY = q1[0, 1]

# Generate grid
x = np.arange(0, 101, 1)
y = np.arange(0, 101, 1)
n = len(x)
minresi1 = 100

# Uniform velocity
v = 6
ndf = N - 3

resi1 = np.zeros((n, n))

# Compute range to each station and residuals
for i in range(n):
    for j in range(n):
        r =
        t = r / v
        ot1 = np.mean(ts1 - t)
        tpred = ot1 + t
        resi1[i, j] =

        if resi1[i, j] < minresi1:
            minresi1 = resi1[i, j]
            index1x = i
            index1y = j
            t1 = ot1
            sigma = resi1[i, j] / ndf

x1 = x[index1x]
y1 = y[index1y]
tp1 = np.sqrt((x1 - stationx)**2 + (y1 - stationy)**2) / v + t1

sx1 = np.sqrt(resi1 / ndf)

# Plot
plt.figure()
plt.plot(stationx, stationy, '^g')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, sx1.T, levels=np.arange(0,3,0.2))
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc1 best location')
#plt.savefig('chapter5_eqloc1.pdf')

# Calculate chi-square values
chi2_values = resi1 / sigma
lim95 = chi2.ppf(0.95, ndf)
rows, cols = np.where(chi2_values < lim95)

# Plot uncertainty
plt.figure()
plt.plot(stationx, stationy, '^g')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, chi2_values.T, levels=np.arange(0, 51, 5))
plt.plot(x[rows], y[cols], '.')
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc1 95% confident limit')

plt.show()

# %% [markdown]
# This is the second earthquake

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Load data
q2 = np.array([[60.   , 80.   , 10.   ],
       [ 9.   , 24.   , 22.64 ],
       [24.   , 13.2  , 22.457],
       [33.   ,  4.8  , 23.399],
       [45.   , 10.8  , 21.937],
       [39.   , 27.   , 19.673],
       [54.   , 30.   , 18.255],
       [15.   , 39.   , 20.236],
       [36.   , 42.   , 17.511],
       [27.   , 48.   , 17.826],
       [48.   , 48.   , 15.803],
       [15.   , 42.   , 19.996],
       [18.   , 15.   , 22.872],
       [30.   , 36.   , 18.846]])
stationx = q2[1:, 0]
stationy = q2[1:, 1]
ts1 = q2[1:, 2]
N = len(stationx)
originalX = q2[0, 0]
originalY = q2[0, 1]

# Generate grid
x = np.arange(0, 101, 1)
y = np.arange(0, 101, 1)
n = len(x)
minresi1 = 100

# Uniform velocity
v = 6
ndf = N - 3

resi1 = np.zeros((n, n))

# Compute range to each station and residuals
for i in range(n):
    for j in range(n):
        r = np.sqrt((x[i] - stationx)**2 + (y[j] - stationy)**2)
        t = r / v
        ot1 = np.mean(ts1 - t)
        tpred = ot1 + t
        resi1[i, j] = np.sum((tpred - ts1)**2)

        if resi1[i, j] < minresi1:
            minresi1 = resi1[i, j]
            index1x = i
            index1y = j
            t1 = ot1
            sigma = resi1[i, j] / ndf

x1 = x[index1x]
y1 = y[index1y]
tp1 = np.sqrt((x1 - stationx)**2 + (y1 - stationy)**2) / v + t1

sx1 = np.sqrt(resi1 / ndf)

# Plot
plt.figure()
plt.plot(stationx, stationy, '^g')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, sx1.T, levels=np.arange(0, 5, 0.2))
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc2 best location')

# Calculate chi-square values
chi2_values = resi1 / sigma
lim95 = chi2.ppf(0.95, ndf)
rows, cols = np.where(chi2_values < lim95)

# Plot uncertainty
plt.figure()
plt.plot(stationx, stationy, '^g')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, chi2_values.T, levels=np.arange(0, 51, 5))
plt.plot(x[rows], y[cols], '.')
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc2 95% confident limit')

plt.show()

# %% [markdown]
# Now consider the effect of variations in velocity

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Load data
q1 = np.array([[30.   , 30.   , 10.   ],
       [ 9.   , 24.   , 15.356],
       [24.   , 13.2  , 14.082],
       [33.   ,  4.8  , 13.981],
       [45.   , 10.8  , 14.118],
       [39.   , 27.   , 11.115],
       [54.   , 30.   , 13.838],
       [15.   , 39.   , 14.481],
       [36.   , 42.   , 11.836],
       [27.   , 48.   , 14.554],
       [48.   , 48.   , 14.022],
       [15.   , 42.   , 15.232],
       [18.   , 15.   , 14.656],
       [30.   , 36.   , 11.365]])
stationx = q1[1:, 0]
stationy = q1[1:, 1]
ts1 = q1[1:, 2]
N = len(stationx)
originalX = q1[0, 0]
originalY = q1[0, 1]

# Generate grid
x = np.arange(0, 101, 1)
y = np.arange(0, 101, 1)
n = len(x)
minresi1 = 100

# Uniform velocity
v = 6
ndf = N - 3

resi1 = np.zeros((n, n))

# Compute range to each station and residuals
for i in range(n):
    for j in range(n):
        r = np.sqrt((x[i] - stationx)**2 + (y[j] - stationy)**2)
        t = r / v
        ot1 = np.mean(ts1 - t)
        resi1[i, j] = np.sum(((t + ot1) - ts1)**2)

        if resi1[i, j] < minresi1:
            minresi1 = resi1[i, j]
            index1x = i
            index1y = j
            t1 = ot1
            rbest = r
            sigma = resi1[i, j] / ndf

x1 = x[index1x]
y1 = y[index1y]

sx1 = resi1 / ndf
chi2_values = resi1 / sigma

# Plot
plt.figure()
N1 = np.where(stationx <= 30)[0]
N2 = np.where(stationx > 30)[0]
plt.plot(stationx[N1], stationy[N1], '^y')
plt.plot(stationx[N2], stationy[N2], '^g')
plt.legend(['slow side', 'fast side'])
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, sx1.T, levels=np.arange(0, 21, 0.5))
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc3 best location')

plt.figure()

lim95 = chi2.ppf(0.95, ndf)
rows, cols = np.where(chi2_values < lim95)
plt.plot(stationx[N1], stationy[N1], '^y')
plt.plot(stationx[N2], stationy[N2], '^g')
plt.legend(['slow side', 'fast side'])
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.contour(x, y, chi2_values.T, levels=np.arange(0, 5, 0.2))
plt.plot(x[rows], y[cols], '.')
plt.plot(x1, y1, 'ro')
plt.plot(originalX, originalY, 'r*')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.grid(True)
plt.title('chapter5 eqloc3 95% confident limit')

plt.show()
