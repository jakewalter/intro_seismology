# %% [markdown]
# <a href="https://colab.research.google.com/github/jakewalter/intro_seismology/blob/main/linear_inversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recall from the lecture material the inversion for the model estimate and use this information to complete the script

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic dataset
X = np.linspace(0, 10, 20)
a = 2
b = 4
Y = a + b * X + np.random.randn(len(X))

# Plot synthetic data
plt.plot(X, Y, 'o-')
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Perform inversion, generate d, G.
d = Y  # data vector
G = np.vstack((np.ones_like(X), X)).T  # G matrix
m =

# %% [markdown]
# Now compute the L2 norm and report the misfit

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dpred = G.dot(m)  # model prediction
residual =  # misfit at each data point
misfit =  # L2 norm
print(misfit)

plt.plot(X, Y, 'o-')
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.plot(X, dpred, 'r-')
plt.show()
