# %% [markdown]
# <a href="https://colab.research.google.com/github/jakewalter/intro_seismology/blob/main/wave_equation_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set up you variables here

# Main loop fix for your range of times (T
for :
    t = T[it]
    for i in range(1, 99):
        rhs = beta**2 * (u2[i+1] - 2 * u2[i] + u2[i-1]) / dx**2
        u3[i] = dt**2 * rhs + 2 * u2[i] - u1[i]

    # Apply boundary conditions
    u3[0] = u3[1]  # Stress-free boundary condition at 0 km
    u3[99] = 0    # Fixed boundary at 100 km

    # Apply source term
    if t <= tlen:
        u3[nsource] = np.sin(np.pi * t / tlen)**2

    # Update solution vectors for next time step
    u1[:] = u2[:]
    u2[:] = u3[:]

    #Now plot it within your loop

# %%
len(u2)
# Out:
# 99
